# %% [markdown]
# # Unit34. 클래스(Class)
# ### 클래스와 메소드 만들기

# %%
class Person:       #클래스의 이름은 대문자로 시작
    def greeting(self):    #매소드 제일 첫번째 매개변수 자리엔 'self'
        print('Hello')

# %%
#클래스의 인스턴스(객체)를 만들어야 클래스를 사용할 수 있음
james = Person()    #생성자 함수
maria = Person()

# %%
james.greeting()
# Out:
# Hello

# %%
maria.greeting()
# Out:
# Hello

# %%
Person().greeting()
# Out:
# Hello

# %%
isinstance(james,Person)
# Out:
# True

# %% [markdown]
# - 클래스 내에서 매소드 호출하기

# %%
class Person:
    def greeting(self):
        print('Hello')

    def hello(self):
        self.greeting()  #클래스 내에서 속성이나 매소드를 참조할때 self.xxx

# %%
james = Person()
james.hello()
# Out:
# Hello

# %%
#음수와 실수에 대한 대비가 없다.
def fact(n):
    if n == 0 :
        return 1
    return n * fact(n-1)

# %%
def factorial(n):
    if not isinstance(n, int) or n < 0:
        return None #해결할수 없다.
    if n == 0 :
            return 1
    return n * fact(n-1)

# %%
factorial(1.3), factorial(-4)
# Out:
# (None, None)

# %% [markdown]
# ### 34.2 속성(Attribute)

# %%
class Person:
    def __init__(self):
        self.hello = '안녕하세요?'  #hello가 속성이 된다.
    def greeting(self):
        print(self.hello)

# %%
maria = Person()
maria.greeting()
# Out:
# 안녕하세요?

# %%
# 속성으로 되어 있으면 밖에서 속성값을 수정할 수가 있다!
maria.hello = "How are you?"
maria.greeting()
# Out:
# How are you?

# %%
james = Person()
james.hello = "Good afternoon!"
james.greeting()

# %%
class Person:
    def __init__(self, name, age, address):  # 생성자 함수
        self.hello = '안녕하세요'
        self.name = name
        self.age = age
        self.address = address
    def greeting(self):
        print(f'{self.hello} 저는 {self.name}입니다.')

    def __str__(self):
        return f'hello : {self.hello}, name : {self.name}, age : {self.age}, address : {self.address}'

# %%
maria = Person('마리아', 23 , '서울시 서초구')
maria.greeting()
# Out:
# 안녕하세요 저는 마리아입니다.

# %%
maria.hello = '반갑습니다'
maria.greeting()
# Out:
# 반갑습니다 저는 마리아입니다.

# %%
#__str__객체 만들기 전
print(maria)

# %%
#__str__객체 만든 후
print(maria)
# Out:
# hello : 안녕하세요, name : 마리아, age : 23, address : 서울시 서초구

# %%
maria.hello= "반갑습니다."
print(maria)
# Out:
# hello : 반갑습니다., name : 마리아, age : 23, address : 서울시 서초구

# %% [markdown]
# ### 34.3 비공개 속성

# %%
class Person:
    def __init__(self,name, age,addr, wallet):
        self.name = name
        self.age = age
        self.addr = addr
        self.__wallet = wallet      #__가 붙으면 비공개 속성이 됨

# %%
james = Person('제임스', 25, '서울시 서초구 반포동', 10000)

# %%
james.__wallet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26460/2612972070.py in <module>
# ----> 1 james.__wallet
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
class Person:
    def __init__(self,name, age,addr, wallet):
        self.name = name
        self.age = age
        self.addr = addr
        self.__wallet = wallet    
    def pay(self, amount):
        if self.__wallet < amount:
            print('지갑에 돈이 부족합니다.ㅠㅠ')
            return
        self.__wallet -= amount
        print(f'지갑에 남은 돈은 {self.__wallet:,d}원 입니다.')

    def __greeting(self):
        print('Hello')
    
    def hello(self):
        self.__greeting()

# %%
james = Person('제임스', 25, '서울시 서초구 반포동', 10000)
james.pay(2500)
# Out:
# 지갑에 남은 돈은 7,500원 입니다.

# %%
james.pay(8000)
# Out:
# 지갑에 돈이 부족합니다.ㅠㅠ

# %%
#비공개 메소드
james.__greeting()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26460/326312394.py in <module>
#       1 #비공개 메소드
# ----> 2 james.__greeting()
#
# AttributeError: 'Person' object has no attribute '__greeting'

# %%
james.hello()
# Out:
# Hello

# %% [markdown]
# ##### 연습문제
#  - class Tmoney

# %%
class Tmoney:
    def __init__(self, age, balance):
        self.age = age
        self.balance = balance

    def pay(self):
        if 7 <= self.age <= 12:
            fare = 650
        elif 13 <= self.age <= 18:
            fare = 1050
        elif self.age <= 19:
            fare = 1250
        else:
            fare = 0

        if self.balance < fare:
            print('잔액이 부족합니다.ㅠㅠ')
            return
        self.balance -= fare
        print(f'{self.age}살의 요금은 {self.balance:,d}원입니다, 잔액은 {self.balance:,d}원 입니다')

# %%
card = Tmoney(30, 100)
card.pay()
# Out:
# 30살의 요금은  0원입니다, 잔액은 100원 입니다

# %% [markdown]
# # 다시 확인!

# %%
card = Tmoney(30, 10000)
for i in range(10000):
    card.pay()
# Out:
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# 30살의 요금은  0원입니다, 잔액은 10,000원 입니다
# ...

# %%
class Tcard:
    def __init__(self, balance):
        self.__balance = balance
    
    def get_balance(self):                  #getter 
        return self.__balance

    def pay(self, fare = 1350):
        if self.__balance < fare:
            print('잔액이 부족합니다 ㅠㅠ')
        self.__balance -= fare
        print(f'잔액 : {self.__balance:,d}')

# %%
card = Tcard(10000)
fare = 1350
while card.get_balance() >= fare:
    card.pay()
# Out:
# 잔액 : 8,650
# 잔액 : 7,300
# 잔액 : 5,950
# 잔액 : 4,600
# 잔액 : 3,250
# 잔액 : 1,900
# 잔액 : 550

# %% [markdown]
# #### unit.15
# <pre>
# 표준 입력으로 나이(만 나이)가 입력됩니다(입력 값은 7 이상 입력됨).
# 교통카드 시스템에서 시내버스 요금은 다음과 같으며
# 각 나이에 맞게 요금을 차감한 뒤 잔액이 출력되게 만드세요(if, elif 사용).
# 현재 교통카드에는 9,000원이 들어있습니다.
#
# 어린이(초등학생, 만 7세 이상 12세 이하): 650원
# 청소년(중∙고등학생, 만 13세 이상 18세 이하): 1,050원
# 어른(일반, 만 19세 이상): 1,250원
#
#
# age = int(input())
# balance = 9000    # 교통카드 잔액
#
# ________________
#
# print(balance)
#
# 예
# 입력
# 17
# 결과
# 7950
# 입력
# 12
# 결과
# 8350
# <pre>
